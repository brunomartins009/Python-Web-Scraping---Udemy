# %% [markdown]
# ## Importando as bibliotecas

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from urllib.error import HTTPError, URLError
import re

# %% [markdown]
# ## Códigos

# %% [markdown]
# ### Recuperando a primeira tag `<h1>` e a primeira tag `<title>` do arquivo `teste.html`

# %%
html = urlopen("http://localhost:8000/teste1.html")

bsObj = BeautifulSoup(html.read(), "html.parser")

print(bsObj.h1)
print(bsObj.title)
# Out:
# <h1>Python Web Scraping</h1>
# <title>Testando servidor web</title>

# %% [markdown]
# ### Recuperando todas as tags `<h1>` e a tag `<title>` do arquivo `teste.html`

# %%
html = urlopen("http://localhost:8000/teste2.html")

bsObj = BeautifulSoup(html.read(), "html.parser")

# print(bsObj.h1)
print(bsObj.find_all("h1"))
print(bsObj.title)
# Out:
# [<h1>Python Web Scraping</h1>, <h1>Aula 2</h1>]
# <title>Testando servidor web</title>

# %% [markdown]
# ### Recuperando todas as tags `<a>` do arquivo `teste.html`

# %%
html = urlopen("http://localhost:8000/teste3.html")

bsObj = BeautifulSoup(html.read(), "html.parser")

# -------------- Imprime em forma de lista --------------
# print(bsObj.find_all("a"))

# -------------- Imprime uma por uma --------------
# for link in bsObj.find_all("a"):
#     print(link)

# -------------- Imprime apenas o link --------------
for link in bsObj.find_all("a"):
    print(link.get("href"))
# Out:
# http://www.google.com
# http://www.udemy.com
# http://www.cursoemvideo.com
# http://www.youtube.com

# %% [markdown]
# ### Tratando erros

# %%
# Demonstração do erro

html = urlopen("http://localhost:8000/teste3.html")
print(f"Html 1: {html}")

html = urlopen("http://localhost:8000/teste3.html/erro")
print(f"Html 1: {html}")

html = urlopen("http://localhost:8000/teste3.html")
print(f"Html 1: {html}")
# Out:
# Html 1: <http.client.HTTPResponse object at 0x7aebdd5ae9b0>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3 html = urlopen("http://localhost:8000/teste3.html")
#       4 print(f"Html 1: {html}")
# ----> 6 html = urlopen("http://localhost:8000/teste3.html/erro")
#       7 print(f"Html 1: {html}")
#       9 html = urlopen("http://localhost:8000/teste3.html")
#
# File /usr/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File /usr/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File /usr/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File /usr/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /usr/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: File not found

# %%
# Tratando o erro

html = urlopen("http://localhost:8000/teste3.html")
print(f"Html 1: {html}")

try:
    html = urlopen("http://localhost:8000/teste3.html/erro")
    print(f"Html 1: {html}")
except HTTPError as erro:
    print(f"Erro HTTP: {erro}")

try:
    html = urlopen("http:www.hhdjshkd.com")
    print(f"Html 1: {html}")
except URLError as erro:
    print(f"Erro URL: {erro}")
# Out:
# Html 1: <http.client.HTTPResponse object at 0x7aebdc1d4af0>
# Erro HTTP: HTTP Error 404: File not found
# Erro URL: <urlopen error no host given>

# %%
# Erro de tag não existente

# Mostrando o erro

html = urlopen("http://localhost:8000/teste3.html")
bsObj = BeautifulSoup(html.read(), "html.parser")

resultado = bsObj.tag_nao_existente.tag_nao_existente2
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 8
#       5 html = urlopen("http://localhost:8000/teste3.html")
#       6 bsObj = BeautifulSoup(html.read(), "html.parser")
# ----> 8 resultado = bsObj.tag_nao_existente.tag_nao_existente2
#       9 print(resultado)
#
# AttributeError: 'NoneType' object has no attribute 'tag_nao_existente2'

# %%
# Erro de tag não existente

# Tratando o erro

html = urlopen("http://localhost:8000/teste3.html")
bsObj = BeautifulSoup(html.read(), "html.parser")

try:
    resultado = bsObj.tag_nao_existente.tag_nao_existente2
    print(resultado)
except AttributeError as erro:
    print(f"Erro de atributo: {erro}")
# Out:
# Erro de atributo: 'NoneType' object has no attribute 'tag_nao_existente2'

# %%
def getTitulo(url):
    try:
        html = urlopen(url)
    except HTTPError as erro:
        print(f"Erro HTTP: {erro}")
    except URLError as erro:
        print(f"Erro URL: {erro}")
    except:
        print("Erro desconhecido")
    
    try:
        bsObj = BeautifulSoup(html.read(), "html.parser")
        titulo = bsObj.body.h1
    except AttributeError as erro:
        print(f"Erro de atributo: {erro}")
        return None
    except:
        print("Erro desconhecido")
        return None
    return titulo

titulo = getTitulo(input("Digite a URL: "))

if titulo is not None:
    print(titulo)
else:
    print("O título não foi encontrado")
# Out:
# <h1>Bruno Martins</h1>

# %% [markdown]
# ### Um pouco mais sobre BeautifulSoup

# %%
html = urlopen("https://evaldowolkers.wordpress.com")
bsObj = BeautifulSoup(html, "html.parser")

teste = bsObj.find_all(class_="comments-link")
for a in teste:
    print(a)

python = bsObj.find_all(string="Python")
for a in python:
    print(a)
# Out:
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2019/01/06/switch-em-python/#comments">2 comentários<span class="screen-reader-text"> em Switch em Python</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2018/12/12/traducao-de-texto-com-python-e-googletrans/#respond">Deixe um comentário<span class="screen-reader-text"> em Tradução de Texto com Python e Googletrans</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2018/11/21/lendo-arquivos-pdf-com-python/#comments">3 comentários<span class="screen-reader-text"> em Lendo arquivos PDF com Python</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2018/10/20/enviando-e-mails-simples-com-python/#respond">Deixe um comentário<span class="screen-reader-text"> em Enviando e-mails simples com Python</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2018/02/18/instalando-o-bash-linux-no-windows-10/#respond">Deixe um comentário<span class="screen-reader-text"> em Instalando o Bash Linux no Windows 10</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2018/02/07/terminal-linux-e-prompt-de-comando-do-windows/#respond">Deixe um comentário<span class="screen-reader-text"> em Terminal Linux e Prompt de Comando do Windows</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2017/12/08/configurando-dicionario-pt-br-para-corretor-ortografico-do-pycharm/#comments">2 comentários<span class="screen-reader-text"> em Configurando Dicionário PT-BR para Corretor Ortográfico do PyCharm</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2017/03/10/curso-de-python-aula-9/#comments">2 comentários<span class="screen-reader-text"> em Curso de Python – Aula 9</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2017/02/10/curso-de-python-aula-8/#respond">Deixe um comentário<span class="screen-reader-text"> em Curso de Python – Aula 8</span></a></span>
# <span class="comments-link"><a href="https://evaldowolkers.wordpress.com/2017/01/17/curso-de-python-aula-7/#respond">Deixe um comentário<span class="screen-reader-text"> em Curso de Python – Aula 7</span></a></span>
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python

# %%
# .get_text() - Retorna apenas o texto, sem as tags HTML
print(bsObj.get_text())

# .tag - Retorna a primeira ocorrência da tag
print(bsObj.title)

# .tag.name - Retorna o nome da tag
print(bsObj.title.name)

# .tag.string - Retorna o conteúdo da tag
print(bsObj.title.string)
# Out:
# Evaldo Wolkers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			Ir para conteúdo
#
#
#
#
# Evaldo Wolkers
#
# Menu
#
#
# Home
# Cursos
# Livros
# Sobre
#
#
#
#
#
#
#
#
#
# Switch em Python
#
# No Python temos a estrutura condicional if-elif-else.
# Algumas linguagens, como Java e C possuem uma estrutura denominada “switch” que não existe no Python.
# No switch o conteúdo de uma variável é comparado com um valor constante e, caso a comparação seja verdadeira, um determinado comando é executado. O switch pode ser usado por exemplo para criar um menu com opções onde o usuário escolhe uma das opções e instruções são executadas de acordo com essa escolha.
# A sintaxe do switch nessas linguagens é a seguinte:
# switch(variável)
# {
#     case constante1:
#         instruções;
#         break;
#     case constante2:
#         instruções;
#         break;
#     case constante3:
#         instruções;
#         break;
#     default:
#         instruções caso nenhuma opção tenha sido escolhida;
# }
# No Python não temos o switch, porém, podemos implementar algo parecido usando dicionários. Vamos criar uma função chamada meu_switch que terá o mesmo resultado do switch existente na linguagem C.
# def meu_switch(opcao):
#     opcoes = {
#         0: "Você escolheu zero",
#         1: "Você escolheu 1",
#         2: "Você escolheu 2",
#     }
#     return opcoes.get(opcao, "Opção inválida.")
#
# if __name__ == "__main__":
#     opcao = int(input("Informe um número de 0 a 2: "))
#     print (meu_switch(opcao))
#
#
# Autor  evaldowolkersPublicado em janeiro 6, 2019janeiro 6, 2019Categorias Python2 comentários em Switch em Python
#
#
#
# Tradução de Texto com Python e Googletrans
#
# Googletrans é uma biblioteca Python gratuita e ilimitada que implementa a Google Translate API. Esta biblioteca usa o Google Translate Ajax API para fazer chamadas para métodos como detectar e traduzir.
#
# Podemos instalar com o Pypi:
# $ pip install googletrans
#
# No momento em que escrevo este post existe um problema com a biblioteca, porém, a solução já foi reportada no Github do projeto, mas como o pull request ainda não foi aceito e a biblioteca continua com o problema, vou desinstalar a versão oficial e instalar uma versão não oficial onde o problema já foi resolvido:
# $ pip uninstall googletrans
# $ git clone https://github.com/BoseCorp/py-googletrans.git
# $ cd ./py-googletrans
# $ python setup.py install
#
# Veja um exemplo básico de uso:
#
# Veja o resultado:
#
#
# Podemos traduzir uma lista de strings (Tradução em massa).
#
# Veja o resultado:
#
#
# Podemos também detectar o idioma:
#
# Veja o resultado:
#
#
# Traduzindo um texto informado pelo usuário (Inglês/Português).
#
#
# Este exemplo é parte da aula “Usando o Googletrans” do curso Python para Todos que pode ser adquirido em https://www.udemy.com/python-3-para-todos/
#
# Repositório do curso no GitHub:
# https://github.com/evaldowolkers/PythonParaTodos
#
#
#
#
#
# Autor  evaldowolkersPublicado em dezembro 12, 2018dezembro 15, 2018Categorias UncategorizedDeixe um comentário em Tradução de Texto com Python e Googletrans
#
#
#
# Lendo arquivos PDF com Python
#
# Para trabalhar com arquivos PDF podemos usar a biblioteca PDFMiner3k.
# Podemos instalar esta biblioteca utilizando o pip.
# $ pip install pdfminer3k
#
# Veja a seguir as importações necessárias para trabalharmos com o arquivo PDF.
# from pdfminer.pdfinterp import PDFResourceManager, process_pdf
# from pdfminer.converter import TextConverter
# from pdfminer.layout import LAParams
# from io import StringIO
# from urllib.request import urlopen
# Agora veja a função que realiza a leitura de um arquivo PDF e retorna o texto deste arquivo.
# def lerPDF(arquivoPDF):
#     # PDFResourceManager Usado para armazenar recursos compartilhados
#     # como fontes e imagens
#     recursos = PDFResourceManager()
#     buffer = StringIO()
#     layoutParams = LAParams()
#     dispositivo = TextConverter(recursos, buffer, laparams=layoutParams)
#     process_pdf(recursos, dispositivo, arquivoPDF)
#     dispositivo.close()
#     conteudo = buffer.getvalue()
#     buffer.close()
#     return conteudo
# Realizando a chamada à função:
# # Abrindo arquivo PDF online
# arquivoPDF = urlopen(“https://s3.novatec.com.br/sumarios/sumario-9788575226926.pdf&#8221;)
# stringSaida = lerPDF(arquivoPDF)
# print(stringSaida)
# arquivoPDF.close()
# Programa sendo executado.
#
# Este exemplo é parte da aula “Lendo Documentos: Arquivos PDF” do curso Python Web Scraping que pode ser adquirido em https://www.udemy.com/python-web-scraping
#
#
# Autor  evaldowolkersPublicado em novembro 21, 2018novembro 21, 2018Categorias Uncategorized3 comentários em Lendo arquivos PDF com Python
#
#
#
# Enviando e-mails simples com Python
#
#
# Para enviar e-mails simples (sem formatação) utilizando o Python podemos utilizar o módulo smtplib que é um módulo disponível por padrão no Python. O módulo smtplib define um objeto de sessão de cliente SMTP que pode ser utilizado para enviar e-mails para todos computadores conectados à Internet que possuam o serviço de processamento SMTP ou ESMTP.
# Antes de implementarmos nossos exemplos vamos primeiro ver alguns conceitos:
# SMTP
# Simple Mail Transfer Protocol (abreviado SMTP. Traduzido do inglês, significa “Protocolo de transferência de correio simples”) é o protocolo padrão para envio de e-mails através da Internet.
# É um protocolo relativamente simples, em texto plano, onde um ou vários destinatários de uma mensagem são especificados (e, na maioria dos casos, validados) sendo, depois, a mensagem transferida. Esse protocolo usa por padrão a porta TCP 25 (ou 465 para conexão criptografada via SSL). No Brasil, porém, desde 2013, provedores e operadoras de internet passaram a utilizar a porta 587, como medida de segurança para diminuir o número de spams.
# O SMTP é um protocolo de envio apenas, o que significa que ele não permite que um usuário descarregue as mensagens de um servidor. Para isso, é necessário um cliente de e-mail com suporte ao protocolo POP3 ou IMAP, o que é o caso da maioria dos clientes atuais.
# SSL
# O SSL (Secure Sockets Layer) é um protocolo de segurança criado pela Netscape que se tornou padrão internacional para troca de informações sigilosas na Internet.
# TLS
# O Transport Layer Security (TLS), assim como o seu antecessor Secure Sockets Layer (SSL), é um protocolo de segurança que protege as telecomunicações via internet para serviços como e-mail (SMTP), navegação por páginas (HTTPS) e outros tipos de transferência de dados.
# Enviando e-mail sem SSL ou TLS (O servidor de e-mail deve permitir o envio sem criptografia).
#
# A classe SMTP suporta a declaração with. Quando usamos with, o comando QUIT é executado automaticamente. Se não utilizarmos with, teremos que usar o método quit() ao final do envio.
# Enviando e-mail com criptografia SSL usando GMail.
#
# Ao tentar enviar e-mail usando o SMTP do GMail, se ocorrer um erro com a mensagem a seguir, você terá que entrar na conta que está utilizando e permitir a execução de aplicativos menos seguros.
# Erro exibido ao executar o sistema:
# Please log in via your web browser and then try again. Learn more at https://support.google.com/mail/answer/78754
# Link para permitir aplicativos menos seguros:
# https://myaccount.google.com/lesssecureapps
#
# Ative esta opção:
#
# Após ativar, você conseguirá usar a conta para enviar e-mail via smtplib.
# Enviando e-mail com criptografia TLS usando GMail.
#
#
# O GMail utiliza a porta 465 para SSL e 587 para TLS.
# Os exemplos podem ser obtidos em:
# https://github.com/evaldowolkers/PythonParaTodos/tree/master/Secao35-TrabalhandoComE-mail/Aula01_EnviandoEmailsSimples/codigo
#
#
# Autor  evaldowolkersPublicado em outubro 20, 2018outubro 21, 2018Categorias PythonTags Desenvolvimento, Developer, Development, E-mail, Python, smtplibDeixe um comentário em Enviando e-mails simples com Python
#
#
#
# Instalando o Bash Linux no Windows 10
#
#
#
#
#
#
# Autor  evaldowolkersPublicado em fevereiro 18, 2018fevereiro 18, 2018Categorias Sistemas OperacionaisDeixe um comentário em Instalando o Bash Linux no Windows 10
#
#
#
# Terminal Linux e Prompt de Comando do Windows
#
#
# Nesta data publiquei um curso gratuito na plataforma da Udemy.
# Mas qual o motivo do curso de terminal Linux e prompt de comando do Windows?
# Desde a época em que eu dava aula de Delphi recebia alunos que vinham de cursos básicos sem saber criar uma pasta ou descobrir o local onde haviam salvo os projetos e arquivos de código-fonte.
# Tenho amigos e parentes que insisti que usassem Linux porque volta e meia tinha que formatar seus computadores. Alguns estão usando a mais de dois anos sem precisar formatar, ufa, rs.
# Na empresa onde trabalho tenho colocado Linux em todos setores que posso e alguns funcionários precisam também de um conhecimento melhor de linha de comandos.
# No meu curso Python para Todos também existem alunos que dizem que não estão tão confortáveis quando vou ao prompt ou terminal para executar algum comando e tentam reproduzir.
# Bom, existem milhares de cursos, vídeos manuais, etc., falando sobre isso, afinal de contas, isso existe desde o MS-DOS e o primeiro Unix, kkkk.
# Mas fica como um desafio pessoal, um projeto que sei que me fará bem.
# Minha intenção é fazer um paralelo entre o Linux e Windows, mostrando comandos similares sempre que possível.
# E espero realmente abrir a mente de quem quer que precise.
# Segue link do curso:
# https://www.udemy.com/terminal-linux-e-prompt-de-comando-do-windows
# Abraços,
# Evaldo Wolkers.
#
#
# Autor  evaldowolkersPublicado em fevereiro 7, 2018fevereiro 20, 2018Categorias Cursos, Sistemas OperacionaisDeixe um comentário em Terminal Linux e Prompt de Comando do Windows
#
#
#
# Configurando Dicionário PT-BR para Corretor Ortográfico do PyCharm
#
# Ao utilizar o PyCharm, você verá que algumas palavras serão sublinhadas caso o PyCharm não conheça tal palavra. Na instalação padrão do PyCharm não existe um dicionário PT-BR para utilização.
# Veja:
#
# Para configurar o corretor ortográfico do PyCharm para PT-BR, primeiro precisaremos de um dicionário PT-BR, que é um arquivo de texto simples, contendo palavras em português para sua utilização com o PyCharm.
# Você também poderá criar o seu próprio arquivo contendo palavras que queira que o PyCharm reconheça.
# Vou indicar que faça download de um arquivo pronto em um projeto que encontrei no GitHub do Rafael Sliveira Cordeiro:
# https://github.com/rafaelsc/IntelliJ.Portuguese.Brazil.Dictionary
# O projeto contém 4 arquivos de dicionários:
# portuguese-brazil.dic
# portuguese-brazil_technical-terms.dic
# portuguese-brazil_technical-terms_without-accents.dic
# portuguese-brazil_without-accents.dic
# Baixe os 4 ou apenas o primeiro.
# Após salvar o(s) arquivo(s), Abra o Pycharm e acesse o menu File, opção Default Settings:
#
# Na tela Default Settings, abra a opção Editor e selecione a opção Spelling.
# você verá na parte direita da tela duas abas, Accepted Words e Dictionaries.
#
# Em Accepted Words, você pode clicar no botão com sinal de “+” e adicionar palavras individualmente, mas, como queremos adicionar um arquivo de dicionário contendo inúmeras palavras, vamos selecionar a aba Dictionaries. Observa que na parte inferior existem alguns dicionários padrões (english.dic, jetbrains.dic, python.dic, pythonExtras.dic e django.dic).
# Na parte superior, em Custom Dictionaries Folder, clique no sinal de “+”, e selecione a pasta onde você salvou o(s) arquivo(s) de dicionário.
# Veja na imagem abaixo que eu adicionei a pasta “C:/Temp/wordlist” e dentro da pasta estão os arquivos “portuguese-brazil.dic”, que baixei do projeto citado e “pycharm.dic”, que é um arquivo de texto simples que adicionei algumas palavras (cada palavra tem que estar em uma única linha).
#
# Ao final clique em “OK”, a configuração somente será aceita em novos projetos, caso queira aplicar ao projeto atual (aberto), tem que entrar em File, opção Settings e realizar a configuração especificamente para o projeto, o caminho é o mesmo.
# Feito isto, o PyCharm já estará conhecendo a maioria das palavras da língua portuguesa. Veja que em nosso exemplo não temos mais as palavras sublinhadas porque o corretor já as identifica pelos dicionários adicionados.
#
# Espero ter ajudado, abraços.
#
#
# Autor  evaldowolkersPublicado em dezembro 8, 2017dezembro 8, 2017Categorias PyCharm2 comentários em Configurando Dicionário PT-BR para Corretor Ortográfico do PyCharm
#
#
#
# Curso de Python – Aula 9
#
#
#
#
#
# Curso de Python Mania de Código
#
# Listas
#
# Link para download do material em PDF:
# https://1drv.ms/b/s!AtMp9EatSTXxhyw8tGEI38Cdd9BZ
# Link para download dos exemplos:
# https://1drv.ms/u/s!AtMp9EatSTXxhy6_RpDFrlR2AxCi
# Contatos do instrutor:
# evaldowolkers@gmail.com
# facebook.com/evaldowolkers
# Whatsapp: (28)99948-3074
# Skype: evaldorw
# evaldowolkers.wordpress.com
# twitter.com/evaldowolkers
# youtube.com/evaldowolkers
#
#
# Autor  evaldowolkersPublicado em março 10, 2017fevereiro 18, 2018Categorias Python2 comentários em Curso de Python – Aula 9
#
#
#
# Curso de Python – Aula 8
#
#
#
#
#
# Curso de Python Mania de Código
# Laços (Estruturas de Repetição)
# – while
# – for
# range
# Link para download do material em PDF:
# https://1drv.ms/b/s!AtMp9EatSTXxhjxrVo-DjJAEV9UU
# Link para download dos exemplos:
# https://1drv.ms/f/s!AtMp9EatSTXxhkI8kOAZG98L8Ysr
# Contatos do instrutor:
# evaldowolkers@gmail.com
# facebook.com/evaldowolkers
# Whatsapp: (28)99948-3074
# Skype: evaldorw
# evaldowolkers.wordpress.com
# twitter.com/evaldowolkers
# youtube.com/evaldowolkers
#
#
# Autor  evaldowolkersPublicado em fevereiro 10, 2017fevereiro 10, 2017Categorias PythonDeixe um comentário em Curso de Python – Aula 8
#
#
#
# Curso de Python – Aula 7
#
#
#
#
#
#
# Curso de Python Mania de Código
# Assuntos:
# – Indentação e Blocos de Código
# – Estruturas Condicionais (Controle de
# Fluxo)
# Link para download do material em PDF:
# https://1drv.ms/b/s!AtMp9EatSTXxhW9tpIyBjHmo-iNZ
# Exemplos:
# https://1drv.ms/f/s!AtMp9EatSTXxhgVEkLChmnwVqlr_
#
# Contatos do instrutor:
# evaldowolkers@gmail.com
# facebook.com/evaldowolkers
# Whatsapp: (28)99948-3074
# Skype: evaldorw
# evaldowolkers.wordpress.com
# twitter.com/evaldowolkers
# youtube.com/evaldowolkers
#
#
# Autor  evaldowolkersPublicado em janeiro 17, 2017fevereiro 18, 2018Categorias PythonDeixe um comentário em Curso de Python – Aula 7
#
#
# Paginação de posts
# Página 1
# Página 2
# Página 3
# Próxima página
#
#
#
#
#
#
#
#
# 			Pesquisar por:
#
#
#
# 		Pesquisar
#
#
#
# Posts recentes
#
#
# Switch em Python
#
#
# Tradução de Texto com Python e Googletrans
#
#
# Lendo arquivos PDF com Python
#
#
# Enviando e-mails simples com Python
#
#
# Instalando o Bash Linux no Windows 10
#
#
# Arquivos
#
# janeiro 2019
# dezembro 2018
# novembro 2018
# outubro 2018
# fevereiro 2018
# dezembro 2017
# março 2017
# fevereiro 2017
# janeiro 2017
# dezembro 2016
# novembro 2016
# março 2016
# julho 2013
# junho 2013
#
# Categorias
#
# Banco de Dados
#
# Criptografia
#
# Cursos
#
# Esteganografia
#
# Metasploit
#
# PyCharm
#
# Python
#
# Segurança da Informação
#
# Sistemas Operacionais
#
# Uncategorized
#
#
#
# Follow Evaldo Wolkers on WordPress.com
#
# Meta
#
# Criar conta Fazer login
# Feed de posts
# Feed de comentários
# WordPress.com
#
#
#
#
#
# Home
# Cursos
# Livros
# Sobre
#
#
# Evaldo Wolkers
#
# Crie um site ou blog no WordPress.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						Evaldo Wolkers
#
#
#
# Crie um site ou blog no WordPress.com
#
#
#
#
#
#
#
#
#
#
#
#
# 		Privacidade e cookies: Esse site utiliza cookies. Ao continuar a usar este site, você concorda com seu uso.
# Para saber mais, inclusive sobre como controlar os cookies, consulte aqui:
#
# 			Política de cookies
#
#
#
#
#
#
#
# Assinar
#
#
#
# Assinado
#
#
#
#
#
#
#
# 				Evaldo Wolkers
#
#
#
#
#
#
#
#
#
#
#
#
# 												Cadastre-me
#
#
#
#
# 											Já tem uma conta do WordPress.com? Faça login agora.
#
#
#
#
#
#
#
#
#
#
#
#
# 				Evaldo Wolkers
#
#
#
#
# Assinar
#
#
#
# Assinado
#
#
# Registre-se
# Fazer login
#
#
# 										Denunciar este conteúdo
#
#
#
# 										Visualizar site no Leitor
#
#
# Gerenciar assinaturas
#
# Esconder esta barra
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Carregando comentários...
#
#
#
#
#
#
# Escreva um Comentário
#
#
#
#
# E-mail (obrigatório)
#
#
#
# Nome (obrigatório)
#
#
#
# Site
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Crie um site como este com o WordPress.comComece agora
#
#
#
# <title>Evaldo Wolkers</title>
# title
# Evaldo Wolkers
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>Evaldo Wolkers</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//s1.wp.com" rel="dns-prefetch">
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//af.pubmine.com" rel="dns-prefetch"/>
# <link href="https://evaldowolkers.wordpress.com/feed/" rel="alternate" title="Feed para Evaldo Wolkers »" type="application/rss+xml"/>
# <link href="https://evaldowolkers.wordpress.com/comments/feed/" rel="alternate" title="Feed de comentários para Evaldo Wolkers »" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script>
# window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s2.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1751981882i&ver=6.8.2-alpha-60439"}};
# /*! This file is auto-generated */
# !function(s,n){var o,i,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),a=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===a[t]})}function u(e,t){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);for(var n=e.getImageData(16,16,1,1),a=0;a<n.data.length;a++)if(0!==n.data[a])return!1;return!0}function f(e,t,n,a){switch(t){case"flag":return n(e,"\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!n(e,"\ud83c\udde8\ud83c\uddf6","\ud83c\udde8\u200b\ud83c\uddf6")&&!n(e,"\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!a(e,"\ud83e\udedf")}return!1}function g(e,t,n,a){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):s.createElement("canvas"),o=r.getContext("2d",{willReadFrequently:!0}),i=(o.textBaseline="top",o.font="600 32px Arial",{});return e.forEach(function(e){i[e]=t(o,e,n,a)}),i}function t(e){var t=s.createElement("script");t.src=e,t.defer=!0,s.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",i=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){s.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+g.toString()+"("+[JSON.stringify(i),f.toString(),p.toString(),u.toString()].join(",")+"));",a=new Blob([e],{type:"text/javascript"}),r=new Worker(URL.createObjectURL(a),{name:"wpTestEmojiSupports"});return void(r.onmessage=function(e){c(n=e.data),r.terminate(),t(n)})}catch(e){}c(n=g(i,f,p,u))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&!n.supports.flag,n.DOMReady=!1,n.readyCallback=function(){n.DOMReady=!0}}).then(function(){return e}).then(function(){var e;n.supports.everything||(n.readyCallback(),(e=n.source||{}).concatemoji?t(e.concatemoji):e.wpemoji&&e.twemoji&&(t(e.twemoji),t(e.wpemoji)))}))}((window,document),window._wpemojiSettings);
# </script>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJx9j9EOgjAMRX/IWX0AnozfMkadg25daMnk7x2JmhgNLze5ve1pLpRsHCfFpBAXk2nxIQmMqNm66eUhMm8yLIQCeseIRplJwHHMVkFLvV8lPBQxHZ3IAf5zSxg8qgAuNeUpoCFbQDFmslrZoivhD6An9h9EtPOEGpI3vZ2hrn5P9r7vtQrpFlJQNOJmJnr7deNd4+XcNV3btaemHZ/rr3QE&amp;cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-emoji-styles-inline-css">
#
# 	img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
# </style>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJylzFsKgCAQQNENlWNhr49oLWmDWZOKj6LdF22hz8uFA5cvlbMJbQJPWRsbQec3JQb9noBw1py1jIPMhhaQ5NRekpFhDjfEdBMyFWMB/6C04vFB0zFWnRBDM/C+2h4i4jhW&amp;cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify {
# 	text-align:justify;
# }
# .has-text-align-justify{text-align:justify;}
# </style>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <link crossorigin="anonymous" href="https://s1.wp.com/_static/??-eJyVzDEOgCAMQNELiQU1Jg7Gs2AlDYpAaInx9ro5O/7hfbiywhTFRYEcKvnIQPXN1RVSa0h4MOxOssVDBXunKoqK34DlDq5F5gb+LIoVH4k/vpyzGYe+03oyw/4AcmU1KQ==&amp;cssminify=yes" id="all-css-4-1" media="all" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://s2.wp.com/_static/??-eJzTLy/QzcxLzilNSS3WzyrWz01NyUxMzUnNTc0rQeEU5CRWphbp5qSmJyZX6uVm5uklFxfr6OPTDpRD5sM02efaGpoZmFkYGRuZGmQBAHPvL0Y=&amp;cssminify=yes" id="all-css-6-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="jetpack-sharing-buttons-style-inline-css">
# .jetpack-sharing-buttons__services-list{display:flex;flex-direction:row;flex-wrap:wrap;gap:0;list-style-type:none;margin:5px;padding:0}.jetpack-sharing-buttons__services-list.has-small-icon-size{font-size:12px}.jetpack-sharing-buttons__services-list.has-normal-icon-size{font-size:16px}.jetpack-sharing-buttons__services-list.has-large-icon-size{font-size:24px}.jetpack-sharing-buttons__services-list.has-huge-icon-size{font-size:36px}@media print{.jetpack-sharing-buttons__services-list{display:none!important}}.editor-styles-wrapper .wp-block-jetpack-sharing-buttons{gap:0;padding-inline-start:0}ul.jetpack-sharing-buttons__services-list.has-background{padding:1.25em 2.375em}
# </style>
# <link crossorigin="anonymous" href="https://s2.wp.com/_static/??-eJx9jEEOAiEQBD/kQECjeDC+ZWEnijIwYWA3/l72op689KFTVXplCCU3zE1z6reYRYfiUwlP0VYZpwxIJE4IFRd10HOU9iFA2iuhCiI7/ROiDt9WxfETT20jCOc4YUIa2D9t5eGA91xRBMZS7ATtPkTZvCtdzNEZt7f2fHq8Afl7R7w=&amp;cssminify=yes" id="all-css-8-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="global-styles-inline-css">
# :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #fff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--dark-gray: #1a1a1a;--wp--preset--color--medium-gray: #686868;--wp--preset--color--light-gray: #e5e5e5;--wp--preset--color--blue-gray: #4d545c;--wp--preset--color--bright-blue: #007acc;--wp--preset--color--light-blue: #9adffd;--wp--preset--color--dark-brown: #402b30;--wp--preset--color--medium-brown: #774e24;--wp--preset--color--dark-red: #640c1f;--wp--preset--color--bright-red: #ff675f;--wp--preset--color--yellow: #ffef8e;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--font-family--albert-sans: 'Albert Sans', sans-serif;--wp--preset--font-family--alegreya: Alegreya, serif;--wp--preset--font-family--arvo: Arvo, serif;--wp--preset--font-family--bodoni-moda: 'Bodoni Moda', serif;--wp--preset--font-family--bricolage-grotesque: 'Bricolage Grotesque', sans-serif;--wp--preset--font-family--cabin: Cabin, sans-serif;--wp--preset--font-family--chivo: Chivo, sans-serif;--wp--preset--font-family--commissioner: Commissioner, sans-serif;--wp--preset--font-family--cormorant: Cormorant, serif;--wp--preset--font-family--courier-prime: 'Courier Prime', monospace;--wp--preset--font-family--crimson-pro: 'Crimson Pro', serif;--wp--preset--font-family--dm-mono: 'DM Mono', monospace;--wp--preset--font-family--dm-sans: 'DM Sans', sans-serif;--wp--preset--font-family--dm-serif-display: 'DM Serif Display', serif;--wp--preset--font-family--domine: Domine, serif;--wp--preset--font-family--eb-garamond: 'EB Garamond', serif;--wp--preset--font-family--epilogue: Epilogue, sans-serif;--wp--preset--font-family--fahkwang: Fahkwang, sans-serif;--wp--preset--font-fa ...
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# </style>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJyNjtEOgjAMRX9IbFAMvhg/xYyl4mDrlrUL8PcW9cFETXzrvTk9LUypspEESUBuGJAhlQ5k0mJhNwsiwVUBhoA5uwmNYrlKvnAV1l5bI8/sSFUcvRGztcwbeJOHsjK9I4YBJRk7vjKEGAkuugs9Ema3Or6PH9KfH7MsHv/HFYTORzs+TpzDqW4P+92xaetmuAM9Zm7Y&amp;cssminify=yes" id="all-css-10-1" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 10]>
# <link rel='stylesheet' id='twentysixteen-ie-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie.css?m=1448353951i&#038;ver=20170530' media='all' />
# <![endif]-->
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='twentysixteen-ie8-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie8.css?m=1493067000i&#038;ver=20170530' media='all' />
# <![endif]-->
# <!--[if lt IE 8]>
# <link rel='stylesheet' id='twentysixteen-ie7-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie7.css?m=1448353951i&#038;ver=20170530' media='all' />
# <![endif]-->
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJx9j1EOgjAMQC/kbFAM/hjPArPMYbcutAtye4fRKD/8NH1NXpMHUzKWo2JU0DsGFEi5A53KYRb/VMQIVgREZ0IzJcthX3gHf2LIJlF2PgqM2BG7srq39cMtySEbYtuq57gC01Prxy11QE2tfXwYAvMybplKiI+9j17RiB2Z6Nu3alt+X8Olak7Hw7luqnp4AWcsZ4Q=&amp;cssminify=yes" id="all-css-16-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="jetpack-global-styles-frontend-style-inline-css">
# :root { --font-headings: unset; --font-base: unset; --font-headings-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif; --font-base-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;}
# </style>
# <link crossorigin="anonymous" href="https://s2.wp.com/wp-content/themes/h4/global.css?m=1420737423i&amp;cssminify=yes" id="all-css-18-1" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpcom-actionbar-placeholder-js-extra">
# var actionbardata = {"siteID":"30708878","postID":"0","siteURL":"http:\/\/evaldowolkers.wordpress.com","xhrURL":"https:\/\/evaldowolkers.wordpress.com\/wp-admin\/admin-ajax.php","nonce":"bee3bd2cf5","isLoggedIn":"","statusMessage":"","subsEmailDefault":"instantly","proxyScriptUrl":"https:\/\/s0.wp.com\/wp-content\/js\/wpcom-proxy-request.js?ver=20211021","i18n":{"followedText":"Novas publica\u00e7\u00f5es deste site agora aparecer\u00e3o no seu <a href=\"https:\/\/wordpress.com\/reader\">Leitor<\/a>","foldBar":"Esconder esta barra","unfoldBar":"Mostrar esta barra","shortLinkCopied":"Link curto copiado."}};
# </script>
# <script id="jetpack-mu-wpcom-settings-js-before">
# var JETPACK_MU_WPCOM_SETTINGS = {"assetsUrl":"https:\/\/s1.wp.com\/wp-content\/mu-plugins\/jetpack-mu-wpcom-plugin\/moon\/jetpack_vendor\/automattic\/jetpack-mu-wpcom\/src\/build\/"};
# </script>
# <script crossorigin="anonymous" src="https://s1.wp.com/_static/??/wp-content/js/rlt-proxy.js,/wp-content/themes/pub/twentysixteen/js/html5.js,/wp-content/blog-plugins/wordads-classes/js/cmp/v2/cmp-non-gdpr.js?m=1720530689j" type="text/javascript"></script>
# <script id="rlt-proxy-js-after">
# 	rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# </script>
# <link href="https://evaldowolkers.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="WordPress.com" name="generator">
# <link href="https://wp.me/24QMu" rel="shortlink"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="website" property="og:type"/>
# <meta content="Evaldo Wolkers" property="og:title"/>
# <meta content="https://evaldowolkers.wordpress.com/" property="og:url"/>
# <meta content="Evaldo Wolkers" property="og:site_name"/>
# <meta content="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=200" property="og:image"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="" property="og:image:alt"/>
# <meta content="pt_BR" property="og:locale"/>
# <meta content="249643311490" property="fb:app_id"/>
# <meta content="@evaldowolkers" name="twitter:creator"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://evaldowolkers.wordpress.com/?openidserver=1" rel="openid.server"/>
# <link href="https://evaldowolkers.wordpress.com/" rel="openid.delegate"/>
# <link href="https://evaldowolkers.wordpress.com/osd.xml" rel="search" title="Evaldo Wolkers" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# <script>
# var wa_client = {}; wa_client.cmd = []; wa_client.config = { 'blog_id': 30708878, 'blog_language': 'pt', 'is_wordads': false, 'hosting_type': 0, 'afp_account_id': null, 'afp_host_id': 5038568878849053, 'theme': 'pub/twentysixteen', '_': { 'title': 'Publicidade', 'privacy_settings': 'Configurações de privacidade' }, 'formats': [ 'belowpost', 'bottom_sticky', 'sidebar_sticky_right', 'sidebar', 'gutenberg_rectangle', 'gutenberg_leaderboard', 'gutenberg_mobile_leaderboard', 'gutenberg_skyscraper' ] };
# </script>
# <script type="text/javascript">
#
# 			window.doNotSellCallback = function() {
#
# 				var linkElements = [
# 					'a[href="https://wordpress.com/?ref=footer_blog"]',
# 					'a[href="https://wordpress.com/?ref=footer_website"]',
# 					'a[href="https://wordpress.com/?ref=vertical_footer"]',
# 					'a[href^="https://wordpress.com/?ref=footer_segment_"]',
# 				].join(',');
#
# 				var dnsLink = document.createElement( 'a' );
# 				dnsLink.href = 'https://wordpress.com/pt-br/advertising-program-optout/';
# 				dnsLink.classList.add( 'do-not-sell-link' );
# 				dnsLink.rel = 'nofollow';
# 				dnsLink.style.marginLeft = '0.5em';
# 				dnsLink.textContent = 'Não venda ou compartilhe minhas informações pessoais';
#
# 				var creditLinks = document.querySelectorAll( linkElements );
#
# 				if ( 0 === creditLinks.length ) {
# 					return false;
# 				}
#
# 				Array.prototype.forEach.call( creditLinks, function( el ) {
# 					el.insertAdjacentElement( 'afterend', dnsLink );
# 				});
#
# 				return true;
# 			};
#
# 		</script>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=32" rel="icon" sizes="32x32"/>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=192" rel="icon" sizes="192x192"/>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=180" rel="apple-touch-icon"/>
# <meta content="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=270" name="msapplication-TileImage"/>
# <script type="text/javascript">
# 	window.google_analytics_uacct = "UA-52447-2";
# </script>
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
# 	_gaq.push(['_setAccount', 'UA-52447-2']);
# 	_gaq.push(['_gat._anonymizeIp']);
# 	_gaq.push(['_setDomainName', 'wordpress.com']);
# 	_gaq.push(['_initData']);
# 	_gaq.push(['_trackPageview']);
#
# 	(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		(document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# 	})();
# </script>
# </meta></link></meta></head>

# %%
# tag.parent - Retorna a tag pai
print(bsObj.title.parent)

# tag.parent.name - Retorna o nome da tag pai
print(bsObj.title.parent.name)

# .tag['atributo'] - Retorna o valor do atributo
print(bsObj.body['class'])

# .find(id="descricao") - Retorna a primeira ocorrência da tag com o id especificado
print(bsObj.find(id="menu-item-147"))
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>Evaldo Wolkers</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//s1.wp.com" rel="dns-prefetch">
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//af.pubmine.com" rel="dns-prefetch"/>
# <link href="https://evaldowolkers.wordpress.com/feed/" rel="alternate" title="Feed para Evaldo Wolkers »" type="application/rss+xml"/>
# <link href="https://evaldowolkers.wordpress.com/comments/feed/" rel="alternate" title="Feed de comentários para Evaldo Wolkers »" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script>
# window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s2.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1751981882i&ver=6.8.2-alpha-60439"}};
# /*! This file is auto-generated */
# !function(s,n){var o,i,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),a=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===a[t]})}function u(e,t){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);for(var n=e.getImageData(16,16,1,1),a=0;a<n.data.length;a++)if(0!==n.data[a])return!1;return!0}function f(e,t,n,a){switch(t){case"flag":return n(e,"\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!n(e,"\ud83c\udde8\ud83c\uddf6","\ud83c\udde8\u200b\ud83c\uddf6")&&!n(e,"\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!a(e,"\ud83e\udedf")}return!1}function g(e,t,n,a){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):s.createElement("canvas"),o=r.getContext("2d",{willReadFrequently:!0}),i=(o.textBaseline="top",o.font="600 32px Arial",{});return e.forEach(function(e){i[e]=t(o,e,n,a)}),i}function t(e){var t=s.createElement("script");t.src=e,t.defer=!0,s.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",i=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){s.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+g.toString()+"("+[JSON.stringify(i),f.toString(),p.toString(),u.toString()].join(",")+"));",a=new Blob([e],{type:"text/javascript"}),r=new Worker(URL.createObjectURL(a),{name:"wpTestEmojiSupports"});return void(r.onmessage=function(e){c(n=e.data),r.terminate(),t(n)})}catch(e){}c(n=g(i,f,p,u))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&!n.supports.flag,n.DOMReady=!1,n.readyCallback=function(){n.DOMReady=!0}}).then(function(){return e}).then(function(){var e;n.supports.everything||(n.readyCallback(),(e=n.source||{}).concatemoji?t(e.concatemoji):e.wpemoji&&e.twemoji&&(t(e.twemoji),t(e.wpemoji)))}))}((window,document),window._wpemojiSettings);
# </script>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJx9j9EOgjAMRX/IWX0AnozfMkadg25daMnk7x2JmhgNLze5ve1pLpRsHCfFpBAXk2nxIQmMqNm66eUhMm8yLIQCeseIRplJwHHMVkFLvV8lPBQxHZ3IAf5zSxg8qgAuNeUpoCFbQDFmslrZoivhD6An9h9EtPOEGpI3vZ2hrn5P9r7vtQrpFlJQNOJmJnr7deNd4+XcNV3btaemHZ/rr3QE&amp;cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-emoji-styles-inline-css">
#
# 	img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
# </style>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJylzFsKgCAQQNENlWNhr49oLWmDWZOKj6LdF22hz8uFA5cvlbMJbQJPWRsbQec3JQb9noBw1py1jIPMhhaQ5NRekpFhDjfEdBMyFWMB/6C04vFB0zFWnRBDM/C+2h4i4jhW&amp;cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify {
# 	text-align:justify;
# }
# .has-text-align-justify{text-align:justify;}
# </style>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <link crossorigin="anonymous" href="https://s1.wp.com/_static/??-eJyVzDEOgCAMQNELiQU1Jg7Gs2AlDYpAaInx9ro5O/7hfbiywhTFRYEcKvnIQPXN1RVSa0h4MOxOssVDBXunKoqK34DlDq5F5gb+LIoVH4k/vpyzGYe+03oyw/4AcmU1KQ==&amp;cssminify=yes" id="all-css-4-1" media="all" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://s2.wp.com/_static/??-eJzTLy/QzcxLzilNSS3WzyrWz01NyUxMzUnNTc0rQeEU5CRWphbp5qSmJyZX6uVm5uklFxfr6OPTDpRD5sM02efaGpoZmFkYGRuZGmQBAHPvL0Y=&amp;cssminify=yes" id="all-css-6-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="jetpack-sharing-buttons-style-inline-css">
# .jetpack-sharing-buttons__services-list{display:flex;flex-direction:row;flex-wrap:wrap;gap:0;list-style-type:none;margin:5px;padding:0}.jetpack-sharing-buttons__services-list.has-small-icon-size{font-size:12px}.jetpack-sharing-buttons__services-list.has-normal-icon-size{font-size:16px}.jetpack-sharing-buttons__services-list.has-large-icon-size{font-size:24px}.jetpack-sharing-buttons__services-list.has-huge-icon-size{font-size:36px}@media print{.jetpack-sharing-buttons__services-list{display:none!important}}.editor-styles-wrapper .wp-block-jetpack-sharing-buttons{gap:0;padding-inline-start:0}ul.jetpack-sharing-buttons__services-list.has-background{padding:1.25em 2.375em}
# </style>
# <link crossorigin="anonymous" href="https://s2.wp.com/_static/??-eJx9jEEOAiEQBD/kQECjeDC+ZWEnijIwYWA3/l72op689KFTVXplCCU3zE1z6reYRYfiUwlP0VYZpwxIJE4IFRd10HOU9iFA2iuhCiI7/ROiDt9WxfETT20jCOc4YUIa2D9t5eGA91xRBMZS7ATtPkTZvCtdzNEZt7f2fHq8Afl7R7w=&amp;cssminify=yes" id="all-css-8-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="global-styles-inline-css">
# :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #fff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--dark-gray: #1a1a1a;--wp--preset--color--medium-gray: #686868;--wp--preset--color--light-gray: #e5e5e5;--wp--preset--color--blue-gray: #4d545c;--wp--preset--color--bright-blue: #007acc;--wp--preset--color--light-blue: #9adffd;--wp--preset--color--dark-brown: #402b30;--wp--preset--color--medium-brown: #774e24;--wp--preset--color--dark-red: #640c1f;--wp--preset--color--bright-red: #ff675f;--wp--preset--color--yellow: #ffef8e;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--font-family--albert-sans: 'Albert Sans', sans-serif;--wp--preset--font-family--alegreya: Alegreya, serif;--wp--preset--font-family--arvo: Arvo, serif;--wp--preset--font-family--bodoni-moda: 'Bodoni Moda', serif;--wp--preset--font-family--bricolage-grotesque: 'Bricolage Grotesque', sans-serif;--wp--preset--font-family--cabin: Cabin, sans-serif;--wp--preset--font-family--chivo: Chivo, sans-serif;--wp--preset--font-family--commissioner: Commissioner, sans-serif;--wp--preset--font-family--cormorant: Cormorant, serif;--wp--preset--font-family--courier-prime: 'Courier Prime', monospace;--wp--preset--font-family--crimson-pro: 'Crimson Pro', serif;--wp--preset--font-family--dm-mono: 'DM Mono', monospace;--wp--preset--font-family--dm-sans: 'DM Sans', sans-serif;--wp--preset--font-family--dm-serif-display: 'DM Serif Display', serif;--wp--preset--font-family--domine: Domine, serif;--wp--preset--font-family--eb-garamond: 'EB Garamond', serif;--wp--preset--font-family--epilogue: Epilogue, sans-serif;--wp--preset--font-family--fahkwang: Fahkwang, sans-serif;--wp--preset--font-fa ...
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# </style>
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJyNjtEOgjAMRX9IbFAMvhg/xYyl4mDrlrUL8PcW9cFETXzrvTk9LUypspEESUBuGJAhlQ5k0mJhNwsiwVUBhoA5uwmNYrlKvnAV1l5bI8/sSFUcvRGztcwbeJOHsjK9I4YBJRk7vjKEGAkuugs9Ema3Or6PH9KfH7MsHv/HFYTORzs+TpzDqW4P+92xaetmuAM9Zm7Y&amp;cssminify=yes" id="all-css-10-1" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 10]>
# <link rel='stylesheet' id='twentysixteen-ie-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie.css?m=1448353951i&#038;ver=20170530' media='all' />
# <![endif]-->
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='twentysixteen-ie8-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie8.css?m=1493067000i&#038;ver=20170530' media='all' />
# <![endif]-->
# <!--[if lt IE 8]>
# <link rel='stylesheet' id='twentysixteen-ie7-css' href='https://s2.wp.com/wp-content/themes/pub/twentysixteen/css/ie7.css?m=1448353951i&#038;ver=20170530' media='all' />
# <![endif]-->
# <link crossorigin="anonymous" href="https://s0.wp.com/_static/??-eJx9j1EOgjAMQC/kbFAM/hjPArPMYbcutAtye4fRKD/8NH1NXpMHUzKWo2JU0DsGFEi5A53KYRb/VMQIVgREZ0IzJcthX3gHf2LIJlF2PgqM2BG7srq39cMtySEbYtuq57gC01Prxy11QE2tfXwYAvMybplKiI+9j17RiB2Z6Nu3alt+X8Olak7Hw7luqnp4AWcsZ4Q=&amp;cssminify=yes" id="all-css-16-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="jetpack-global-styles-frontend-style-inline-css">
# :root { --font-headings: unset; --font-base: unset; --font-headings-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif; --font-base-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;}
# </style>
# <link crossorigin="anonymous" href="https://s2.wp.com/wp-content/themes/h4/global.css?m=1420737423i&amp;cssminify=yes" id="all-css-18-1" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpcom-actionbar-placeholder-js-extra">
# var actionbardata = {"siteID":"30708878","postID":"0","siteURL":"http:\/\/evaldowolkers.wordpress.com","xhrURL":"https:\/\/evaldowolkers.wordpress.com\/wp-admin\/admin-ajax.php","nonce":"bee3bd2cf5","isLoggedIn":"","statusMessage":"","subsEmailDefault":"instantly","proxyScriptUrl":"https:\/\/s0.wp.com\/wp-content\/js\/wpcom-proxy-request.js?ver=20211021","i18n":{"followedText":"Novas publica\u00e7\u00f5es deste site agora aparecer\u00e3o no seu <a href=\"https:\/\/wordpress.com\/reader\">Leitor<\/a>","foldBar":"Esconder esta barra","unfoldBar":"Mostrar esta barra","shortLinkCopied":"Link curto copiado."}};
# </script>
# <script id="jetpack-mu-wpcom-settings-js-before">
# var JETPACK_MU_WPCOM_SETTINGS = {"assetsUrl":"https:\/\/s1.wp.com\/wp-content\/mu-plugins\/jetpack-mu-wpcom-plugin\/moon\/jetpack_vendor\/automattic\/jetpack-mu-wpcom\/src\/build\/"};
# </script>
# <script crossorigin="anonymous" src="https://s1.wp.com/_static/??/wp-content/js/rlt-proxy.js,/wp-content/themes/pub/twentysixteen/js/html5.js,/wp-content/blog-plugins/wordads-classes/js/cmp/v2/cmp-non-gdpr.js?m=1720530689j" type="text/javascript"></script>
# <script id="rlt-proxy-js-after">
# 	rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# </script>
# <link href="https://evaldowolkers.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="WordPress.com" name="generator">
# <link href="https://wp.me/24QMu" rel="shortlink"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="website" property="og:type"/>
# <meta content="Evaldo Wolkers" property="og:title"/>
# <meta content="https://evaldowolkers.wordpress.com/" property="og:url"/>
# <meta content="Evaldo Wolkers" property="og:site_name"/>
# <meta content="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=200" property="og:image"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="" property="og:image:alt"/>
# <meta content="pt_BR" property="og:locale"/>
# <meta content="249643311490" property="fb:app_id"/>
# <meta content="@evaldowolkers" name="twitter:creator"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://evaldowolkers.wordpress.com/?openidserver=1" rel="openid.server"/>
# <link href="https://evaldowolkers.wordpress.com/" rel="openid.delegate"/>
# <link href="https://evaldowolkers.wordpress.com/osd.xml" rel="search" title="Evaldo Wolkers" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# <script>
# var wa_client = {}; wa_client.cmd = []; wa_client.config = { 'blog_id': 30708878, 'blog_language': 'pt', 'is_wordads': false, 'hosting_type': 0, 'afp_account_id': null, 'afp_host_id': 5038568878849053, 'theme': 'pub/twentysixteen', '_': { 'title': 'Publicidade', 'privacy_settings': 'Configurações de privacidade' }, 'formats': [ 'belowpost', 'bottom_sticky', 'sidebar_sticky_right', 'sidebar', 'gutenberg_rectangle', 'gutenberg_leaderboard', 'gutenberg_mobile_leaderboard', 'gutenberg_skyscraper' ] };
# </script>
# <script type="text/javascript">
#
# 			window.doNotSellCallback = function() {
#
# 				var linkElements = [
# 					'a[href="https://wordpress.com/?ref=footer_blog"]',
# 					'a[href="https://wordpress.com/?ref=footer_website"]',
# 					'a[href="https://wordpress.com/?ref=vertical_footer"]',
# 					'a[href^="https://wordpress.com/?ref=footer_segment_"]',
# 				].join(',');
#
# 				var dnsLink = document.createElement( 'a' );
# 				dnsLink.href = 'https://wordpress.com/pt-br/advertising-program-optout/';
# 				dnsLink.classList.add( 'do-not-sell-link' );
# 				dnsLink.rel = 'nofollow';
# 				dnsLink.style.marginLeft = '0.5em';
# 				dnsLink.textContent = 'Não venda ou compartilhe minhas informações pessoais';
#
# 				var creditLinks = document.querySelectorAll( linkElements );
#
# 				if ( 0 === creditLinks.length ) {
# 					return false;
# 				}
#
# 				Array.prototype.forEach.call( creditLinks, function( el ) {
# 					el.insertAdjacentElement( 'afterend', dnsLink );
# 				});
#
# 				return true;
# 			};
#
# 		</script>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=32" rel="icon" sizes="32x32"/>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=192" rel="icon" sizes="192x192"/>
# <link href="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=180" rel="apple-touch-icon"/>
# <meta content="https://evaldowolkers.wordpress.com/wp-content/uploads/2018/12/cropped-20181028_162019.jpg?w=270" name="msapplication-TileImage"/>
# <script type="text/javascript">
# 	window.google_analytics_uacct = "UA-52447-2";
# </script>
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
# 	_gaq.push(['_setAccount', 'UA-52447-2']);
# 	_gaq.push(['_gat._anonymizeIp']);
# 	_gaq.push(['_setDomainName', 'wordpress.com']);
# 	_gaq.push(['_initData']);
# 	_gaq.push(['_trackPageview']);
#
# 	(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		(document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# 	})();
# </script>
# </meta></link></meta></head>
# head
# ['home', 'blog', 'wp-embed-responsive', 'wp-theme-pubtwentysixteen', 'customizer-styles-applied', 'hfeed', 'jetpack-reblog-enabled', 'has-marketing-bar', 'has-marketing-bar-theme-twenty-sixteen']
# <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current_page_item menu-item-home menu-item-147" id="menu-item-147"><a aria-current="page" href="https://evaldowolkers.wordpress.com/">Home</a></li>

# %%
# Encontrar links em que o nome de um dos 6 primeiros classificados
# do campeonato brasileiro de 2025 apareça

paginas = set()
paginas_invalidas = set()
nova_pagina = ""

def abrir_pagina(url_da_pagina):
    global paginas, paginas_invalidas

    try:
        if url_da_pagina not in paginas_invalidas:
            html = urlopen(url_da_pagina)
            bsObj = BeautifulSoup(html, "html.parser")
            serie_a_g6_2025 = ('.flamengo.|.cruzeiro.|.palmeiras.|.bahia.|.botafogo.|.mirassol.')

            for link in bsObj.find_all("a", href=re.compile(serie_a_g6_2025)):
                if "href" in link.attrs:
                    if link.attrs['href'] not in paginas and link.attrs['href'] not in paginas_invalidas:
                        nova_pagina = link.attrs['href']
                        print(nova_pagina)
                        paginas.add(nova_pagina)
                        abrir_pagina(nova_pagina)
                        
    except:
        paginas_invalidas.add(nova_pagina)

abrir_pagina("https://globoesporte.globo.com")
# Out:
# https://ge.globo.com/ba/futebol/times/bahia/
# http://globoesporte.globo.com/ba/futebol/times/bahia/
# https://ge.globo.com/futebol/times/botafogo/
# http://globoesporte.globo.com/futebol/times/botafogo/
# https://ge.globo.com/futebol/times/cruzeiro/
# http://globoesporte.globo.com/futebol/times/cruzeiro/
# https://ge.globo.com/futebol/times/flamengo/
# http://globoesporte.globo.com/futebol/times/flamengo/
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/
# http://globoesporte.globo.com/sp/sorocaba/futebol/times/mirassol/
# https://ge.globo.com/futebol/times/palmeiras/
# http://globoesporte.globo.com/futebol/times/palmeiras/
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/
# http://globoesporte.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/agenda-de-jogos-do-botafogo-sp/#/proximos-jogos
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13920292-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13910392-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13909651-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13906888-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13904367-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13903631-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13894127-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13894048-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13890818-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13890735-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13884672-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13880937-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13875086-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13874137-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13870510-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13864848-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13864620-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13851819-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13851796-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13851797-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13845586-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13845551-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13842189-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13839103-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13839076-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13832537-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13832300-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13832298-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13826761-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13826668-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13826650-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13823300-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13823047-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13820083-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13819700-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13813374-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13808128-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13807213-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13804572-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13803896-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13803895-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13803437-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13800563-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13797322-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13797912-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13794170-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13788949-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13788730-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13785824-id
# https://ge.globo.com/sp/ribeirao-preto-e-regiao/futebol/times/botafogo-sp/playlist/videos-veja-as-reportagens-do-globo-esporte-sobre-o-botafogo-sp.ghtml#video-13784838-id
# https://ge.globo.com/futebol/times/flamengo/noticia/2025/09/12/escalacao-do-flamengo-danilo-entra-no-lugar-de-leo-ortiz-e-time-deve-repetir-dupla-de-la-cruz-e-saul.ghtml
# https://globoesporte.globo.com/futebol/times/flamengo/
# https://ge.globo.com/futebol/times/flamengo/agenda-de-jogos-do-flamengo/#/
# https://ge.globo.com/futebol/times/flamengo/videos/
# https://globoesporte.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13911608-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13892121-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13872522-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13859460-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13840300-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13843184-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13830313-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13770125-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13757782-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13748438-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13727370-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13692242-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13674433-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13667886-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13637440-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13618910-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13618864-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13578416-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13563451-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13560659-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13560669-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13560678-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13538763-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13521176-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13511099-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13504505-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13488606-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13487920-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467578-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467613-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467722-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467829-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467849-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467853-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467907-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467957-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467993-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13467996-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13461945-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13430048-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13430139-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13430387-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13422127-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13417087-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13416643-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13416983-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13403695-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13403558-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13401890-id
# https://ge.globo.com/futebol/times/flamengo/playlist/videos-de-melhores-momentos-do-flamengo.ghtml#video-13384855-id
# https://ge.globo.com/sp/tem-esporte/futebol/noticia/2025/09/12/atacante-do-mirassol-se-espanta-com-flamengo-no-maracana-tocar-um-violino-e-apreciar.ghtml
# https://ge.globo.com/rj/futebol/brasileirao-serie-a/jogo/09-08-2025/flamengo-mirassol.ghtml
# https://ge.globo.com/rj/futebol/brasileirao-serie-a/jogo/25-08-2025/flamengo-vitoria.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/11/flamengo-posta-chapeu-de-arrascaeta-e-jogador-do-mirassol-comenta-melhor-do-brasil.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/10/analise-mirassol-assusta-flamengo-e-mostra-coragem-na-derrota-em-sua-estreia-no-maracana.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/10/baitello-cita-abismo-financeiro-apos-derrota-flamengo-tem-jogador-que-e-o-ano-do-mirassol.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/09/atuacoes-do-mirassol-chico-da-costa-desperdica-gols-e-gabriel-faz-valer-lei-do-ex-de-suas-notas.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/12/escalacao-com-gabriel-de-volta-mirassol-tera-praticamente-forca-maxima-contra-o-gremio.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/10/gabriel-treina-normalmente-e-deve-ser-relacionado-pelo-mirassol-contra-o-gremio.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/09/eliminacao-goleada-e-demissao-de-tecnico-mirassol-tem-100percent-de-aproveitamento-contra-o-gremio.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/copa-do-brasil/jogo/01-03-2022/mirassol-gremio.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/brasileirao-serie-a/jogo/16-04-2025/mirassol-gremio.ghtml
# https://ge.globo.com/rs/futebol/brasileirao-serie-a/noticia/2025/09/11/reinaldo-do-mirassol-revela-sentimento-ao-enfrentar-ex-clube-me-sinto-um-pouco-gremista.ghtml
# https://ge.globo.com/rs/futebol/brasileirao-serie-a/noticia/2025/08/27/flamengo-tem-mais-gols-e-quase-iguala-pontuacao-de-inter-e-gremio-somados.ghtml
# https://ge.globo.com/rs/futebol/brasileirao-serie-a/jogo/24-08-2025/juventude-botafogo.ghtml
# https://ge.globo.com/rs/futebol/brasileirao-serie-a/noticia/2025/08/24/juventude-x-botafogo-onde-assistir-ao-vivo-horario-e-escalacoes.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/11/carlos-eduardo-se-diz-adaptado-ao-mirassol-e-revela-ansiedade-por-1o-gol-nao-vejo-a-hora-de-marcar.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/11/walter-do-mirassol-revela-ter-pensado-em-se-aposentar-no-inicio-do-ano-estava-quase-parando.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/08/guilherme-marques-e-anunciado-como-reforco-do-mirassol.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/26/mirassol-contrata-o-meia-guilherme-marques-ex-goias.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/26/mirassol-acerta-a-contratacao-de-renato-marques-do-america-mg.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/08/25/guanaes-admite-excesso-de-erros-mas-elogia-mirassol-apos-vitoria-cabeca-e-coracao-no-lugar-certo.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/#v/13868839
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/agenda-de-jogos-do-mirassol/#/proximos-jogos
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2025/09/08/paulinho-revela-sonho-de-voltar-a-copa-e-segredos-do-mirassol-nao-sou-diretor-de-reunioes.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2024/11/28/ex-corinthians-e-selecao-brasileira-paulinho-deve-assumir-cargo-de-coordenador-tecnico-do-mirassol.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2024/11/26/alex-muralha-da-volta-por-cima-com-acesso-do-mirassol-e-revela-inspiracao-em-buffon-e-fabio.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2024/11/25/mirassol-sera-o-quinto-cacula-da-serie-a-na-era-dos-pontos-corridos-veja-lista.ghtml
# https://ge.globo.com/sp/tem-esporte/futebol/times/mirassol/noticia/2024/11/25/mirassol-sera-o-time-da-menor-cidade-dos-ultimos-40-anos-do-brasileirao.ghtml

# %%
# Usando expressões regulares para encontrar imagens com beautifulsoup

html = urlopen("https://pythonscraping.com/pages/page3.html")
soup = BeautifulSoup(html, "html.parser")

imagens = soup("img", {"src":re.compile("\.{2}/img/gifts/img\d*\.jpg")})

for imagem in imagens:
    print(imagem['src'])
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_15392/2402207717.py:4: SyntaxWarning: invalid escape sequence '\.'
#   imagens = soup("img", {"src":re.compile("\.{2}/img/gifts/img\d*\.jpg")})
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
# Recuperando links de uma página com BeautifulSoup e expressões regulares

# Erro 403 porque alguns sites bloqueiam o acesso de scraping
# html = urlopen("http://www.tudogostoso.com.br")

req = Request("http://www.tudogostoso.com.br", headers={"User-Agent":" brave/1.0"})
html = urlopen(req).read()

soup = BeautifulSoup(html, "html.parser")

links = soup.find_all("a", {"href":re.compile("/categorias/*")})

for link in links:
    print(link["href"])
# Out:
# https://www.tudogostoso.com.br/categorias/1000-bolos-e-tortas-doces
# https://www.tudogostoso.com.br/categorias/1004-carnes
# https://www.tudogostoso.com.br/categorias/1009-aves
# https://www.tudogostoso.com.br/categorias/1014-peixes-e-frutos-do-mar
# https://www.tudogostoso.com.br/categorias/1023-saladas-molhos-e-acompanhamentos
# https://www.tudogostoso.com.br/categorias/1027-sopas
# https://www.tudogostoso.com.br/categorias/1028-massas
# https://www.tudogostoso.com.br/categorias/1032-bebidas
# https://www.tudogostoso.com.br/categorias/1037-doces-e-sobremesas
# https://www.tudogostoso.com.br/categorias/1044-lanches
# https://www.tudogostoso.com.br/categorias/1334-alimentacao-saudavel
# /categorias

# %%
# Recuperando links que apontem para o próprio site na categoria específica

html = urlopen("https://www.folha.uol.com.br")

soup = BeautifulSoup(html, "html.parser")
links = soup.find_all("a", {"href":re.compile(".*\.folha\.uol\.com\.br/mercado/2025/09/.*\.shtml")})

for link in links:
    print(link["href"])
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_15392/353876098.py:6: SyntaxWarning: invalid escape sequence '\.'
#   links = soup.find_all("a", {"href":re.compile(".*\.folha\.uol\.com\.br/mercado/2025/09/.*\.shtml")})
# https://www1.folha.uol.com.br/mercado/2025/09/medidas-de-haddad-ajudam-a-cumprir-regras-fiscais-mas-nao-controlam-divida-diz-fgv.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/dolar-abre-em-leve-alta-nesta-sexta-12-apos-julgamento-de-bolsonaro.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/pf-prende-careca-do-inss-em-desdobramento-de-operacao-que-apura-fraudes-na-previdencia.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/pf-prende-careca-do-inss-em-desdobramento-de-operacao-que-apura-fraudes-na-previdencia.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/companhias-aereas-brasileiras-gastam-em-acoes-judiciais-o-mesmo-que-arrecadam-com-bagagens.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/companhias-aereas-brasileiras-gastam-em-acoes-judiciais-o-mesmo-que-arrecadam-com-bagagens.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/brasil-tem-8-milhoes-de-empresas-negativadas-e-bate-novo-recorde-diz-serasa.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/pf-prende-careca-do-inss-em-desdobramento-de-operacao-que-apura-fraudes-na-previdencia.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/pf-prende-careca-do-inss-em-desdobramento-de-operacao-que-apura-fraudes-na-previdencia.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/gupy-defende-ia-para-contratacoes-e-rejeita-rotulo-de-vila-somos-so-um-intermediario-diz-ceo.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/gupy-defende-ia-para-contratacoes-e-rejeita-rotulo-de-vila-somos-so-um-intermediario-diz-ceo.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/fast-shop-contrata-ceo-e-promove-reestruturacoes-apos-escandalo-com-icms.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/golpistas-aplicam-golpe-da-falsa-biometria-para-fraudes-financeiras-saiba-como-se-proteger.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/lira-cria-escadinha-de-indicacoes-em-subsidiarias-da-caixa-ate-chegar-ao-minha-casa-minha-vida.shtml
# https://www1.folha.uol.com.br/mercado/2025/09/lira-cria-escadinha-de-indicacoes-em-subsidiarias-da-caixa-ate-chegar-ao-minha-casa-minha-vida.shtml
# https://aovivo.folha.uol.com.br/mercado/2025/09/01/6423-dolar-empresas-e-bolsas-acompanhe-ao-vivo-o-mercado.shtml
# https://aovivo.folha.uol.com.br/mercado/2025/09/01/6423-dolar-empresas-e-bolsas-acompanhe-ao-vivo-o-mercado.shtml
